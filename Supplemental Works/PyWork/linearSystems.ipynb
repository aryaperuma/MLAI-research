# %%
import numpy as np

# %%
A = np.array([[3,-2,1], [1,0,-2], [0,-1,3]])
b = np.array([1,0,1])

# %%
print(A)
# Out:
# [[ 3 -2  1]
#  [ 1  0 -2]
#  [ 0 -1  3]]

# %%
print(b)
# Out:
# [1 0 1]

# %%
z = np.linalg.solve(A,b)
print(z)
# Out:
# [-2. -4. -1.]
